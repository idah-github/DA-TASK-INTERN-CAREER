# %%
#import py libs
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
#Read csv file

df = pd.read_csv(r"C:\Users\Administrator\Desktop\M&E\Data Analytics\Intern Career\Youtube Streamer\youtubers_df.csv")
# df.head(7)
df.rename(columns={'Suscribers': 'Subscribers'}, inplace= True)
# pd.set_option('max_rows', 5, 'max_columns', 10)
df
# Out:
#      Rank              Username           Categories  Subscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# 2           Unknown    7000000.0    24700.0       0.0
# 3             India      15600.0      166.0       9.0
# 4           Unknown    3900000.0    12400.0       0.0
# ..              ...          ...        ...       ...
# 995  Estados Unidos     397400.0    14000.0     124.0
# 996           India    1100000.0    92500.0     164.0
# 997         Unknown     211400.0      745.0       0.0
# 998           India      14000.0       81.0       1.0
# 999           India       2200.0       31.0       1.0
#
#                                                  Links
# 0    http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...
# 1    http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 2    http://youtube.com/channel/UCbCmjCuTUZos6Inko4...
# 3    http://youtube.com/channel/UCpEhnqL0y41EpW2TvW...
# 4    http://youtube.com/channel/UCk8GzjMOrta8yxDcKf...
# ..                                                 ...
# 995  http://youtube.com/channel/UCPKNKldggioffXPkSm...
# 996  http://youtube.com/channel/UCk3fFpqI5kDMf__mUP...
# 997  http://youtube.com/channel/UCdrHrQf0o0TO8YDntX...
# 998  http://youtube.com/channel/UCObyBrdrtQ20BU9PxH...
# 999  http://youtube.com/channel/UCOjgc1p2hJ4GZi6pQQ...
#
# [1000 rows x 9 columns]

# %%
#return column details,type,count..
df.info()
# df['Subscribers'].dtype
# df.columns
# #list row labels and column names
# df.axes
# #get no. dimensions
# df.ndim
# df.shape
# df.size
# #numpy rep of data
# df.values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         1000 non-null   int64
#  1   Username     1000 non-null   object
#  2   Categories   694 non-null    object
#  3   Subscribers  1000 non-null   float64
#  4   Country      1000 non-null   object
#  5   Visits       1000 non-null   float64
#  6   Likes        1000 non-null   float64
#  7   Comments     1000 non-null   float64
#  8   Links        1000 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 70.4+ KB

# %%
#select range of rows
df[998:1000]
#return row ramge with labels
df.loc[11:17,['Username','Subscribers','Likes']]
# #select range of rows&columns using positions
# df.iloc[7:15,[3, 6, 8]]
# df.iloc[-1, 2:4]
# Out:
#                 Username  Subscribers     Likes
# 11    GoldminesTelefilms   89700000.0     421.0
# 12               SonySAB   85400000.0     615.0
# 13  5MinuteCraftsYouTube   80300000.0     703.0
# 14                   BTS   76500000.0  180300.0
# 15            HYBELABELS   72700000.0   23900.0
# 16                 zeetv   72500000.0     144.0
# 17              Pinkfong   69600000.0     397.0

# %%
#check for null cells per column
df.isnull().sum()
# print(df_missing)
#retun row with atleast 1 missing value
df[df.isnull().any(axis=1)].head(9)

# df.notnull().tail(17)
# Out:
#     Rank            Username Categories  Subscribers   Country    Visits  \
# 3      4            SETIndia        NaN  162600000.0     India   15600.0
# 11    12  GoldminesTelefilms        NaN   89700000.0     India   34600.0
# 16    17               zeetv        NaN   72500000.0     India    7300.0
# 20    21            colorstv        NaN   66600000.0     India   14700.0
# 38    39            shemaroo        NaN   48800000.0     India   22600.0
# 41    42           getmovies        NaN   48100000.0   Unknown   55700.0
# 44    45      badabunOficial        NaN   47000000.0    México    6800.0
# 46    47            vootkids        NaN   46000000.0   Unknown  540900.0
# 47    48      ARYDigitalasia        NaN   45900000.0  Pakistán   20000.0
#
#      Likes  Comments                                              Links
# 3    166.0       9.0  http://youtube.com/channel/UCpEhnqL0y41EpW2TvW...
# 11   421.0      13.0  http://youtube.com/channel/UCyoXW-Dse7fURq30EW...
# 16   144.0       1.0  http://youtube.com/channel/UCppHT7SZKKvar4Oc9J...
# 20   413.0       3.0  http://youtube.com/channel/UC55IWqFLDH1Xp7iu1_...
# 38   163.0       7.0  http://youtube.com/channel/UCF1JIbMUs6uqoZEY1H...
# 41   329.0       0.0  http://youtube.com/channel/UClZkHt2kNIgyrTTPnS...
# 44   260.0       4.0  http://youtube.com/channel/UCYWOjHweP2V-8kGKmm...
# 46  3400.0       0.0  http://youtube.com/channel/UCJg19noZp7-BYIGvyp...
# 47   242.0      13.0  http://youtube.com/channel/UC4JCksJF76g_MdzPVB...

# %%
#show thw missing/null data
sbn.heatmap(df.isnull())
plt.show()

# %%
#unique values 
df.nunique()
# df.loc[0:100,['Username','Subscribers','Likes']].duplicated
# df.duplicated()
# Out:
# Rank           1000
# Username        994
# Categories       45
# Subscribers     274
# Country          29
# Visits          713
# Likes           648
# Comments        389
# Links           994
# dtype: int64

# %%
df.sort_values(by= ['Subscribers', 'Visits', 'Country'],
               ascending=[True, True, False]).head()
# Out:
#      Rank           Username           Categories  Subscribers  \
# 999  1000      OneindiaHindi  Noticias y Política   11700000.0
# 992   993  5MinuteCraftsLIKE                  NaN   11700000.0
# 988   989         MykeTowers       Música y baile   11700000.0
# 998   999       PenMultiplex                  NaN   11700000.0
# 987   988                NFL             Deportes   11700000.0
#
#             Country   Visits  Likes  Comments  \
# 999           India   2200.0   31.0       1.0
# 992           India   2700.0   28.0       1.0
# 988        Colombia  11000.0  629.0      18.0
# 998           India  14000.0   81.0       1.0
# 987  Estados Unidos  21400.0  692.0      42.0
#
#                                                  Links
# 999  http://youtube.com/channel/UCOjgc1p2hJ4GZi6pQQ...
# 992  http://youtube.com/channel/UCzTWHWnJ6VIcbkpqyv...
# 988  http://youtube.com/channel/UCLk8IJ1TwI7Xl7UUfA...
# 998  http://youtube.com/channel/UCObyBrdrtQ20BU9PxH...
# 987  http://youtube.com/channel/UCDVYQ4Zhbm3S2dlz7P...

# %%
# df.mean
# df.min
# df.std
#descriptive stats for numeric clmns
df.describe()
df.head(20).describe()
# df[['Subscribers','Visits']].agg(['min','sum','var','std','skew','kurt'])
# Out:
#            Rank   Subscribers        Visits         Likes      Comments
# count  20.00000  2.000000e+01  2.000000e+01  2.000000e+01     20.000000
# mean   10.50000  1.082000e+08  7.073255e+06  2.984273e+05   1776.950000
# std     5.91608  4.729534e+07  2.603471e+07  1.178867e+06   4415.000953
# min     1.00000  6.660000e+07  7.300000e+03  1.440000e+02      0.000000
# 25%     5.75000  7.555000e+07  6.460000e+04  6.810000e+02      0.000000
# 50%    10.50000  9.425000e+07  4.735500e+05  9.350000e+03     17.000000
# 75%    15.25000  1.120000e+08  2.450000e+06  2.552500e+04    393.500000
# max    20.00000  2.495000e+08  1.174000e+08  5.300000e+06  18500.000000

# %%
#outliers
df.boxplot()
# Out:
# <Axes: >

# %%
#find correlation
numeric_df = df.select_dtypes(include=['float64', 'int64'])
numeric_df.head()
numeric_df.corr()
# Out:
#                  Rank  Subscribers    Visits     Likes  Comments
# Rank         1.000000    -0.636552 -0.102714 -0.090913 -0.049194
# Subscribers -0.636552     1.000000  0.245203  0.211639  0.036350
# Visits      -0.102714     0.245203  1.000000  0.950470  0.324067
# Likes       -0.090913     0.211639  0.950470  1.000000  0.325911
# Comments    -0.049194     0.036350  0.324067  0.325911  1.000000

# %%
#visualize correlation among all var
sbn.heatmap(numeric_df.corr(), annot= True)
plt.title('Correlation Matrix')
plt.show()

# %%
#calc and visualiza correlation among specific var
crltn = df[['Subscribers', 'Likes', 'Comments']].corr()
print(crltn)
sbn.heatmap(crltn, annot=True)
plt.show()
# Out:
#              Subscribers     Likes  Comments
# Subscribers     1.000000  0.211639  0.036350
# Likes           0.211639  1.000000  0.325911
# Comments        0.036350  0.325911  1.000000

# %%
#show correlations among var indipendently using scatter graphs
c= sbn.PairGrid(df, vars=['Subscribers', 'Likes', 'Comments'])
c.map(plt.scatter)
plt.show()
#show relationship among var
c = sbn.pairplot(df, size=2.5);
# Out:
# c:\Users\Administrator\Desktop\M&E\Data Analytics\Intern Career\Youtube Streamer\venv\Lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#return random df sample
df.sample(9)
# Out:
#      Rank         Username              Categories  Subscribers  \
# 75     76             TEDx                     NaN   39100000.0
# 429   430   SebastianYatra          Música y baile   18200000.0
# 865   866          TimbaVk  Animación, Videojuegos   12600000.0
# 473   474         Willyrex    Películas, Animación   17200000.0
# 686   687  nikkietutorials    Diseño/arte, Belleza   14400000.0
# 532   533           antrax               Animación   16200000.0
# 523   524       mattstonie         Comida y bebida   16400000.0
# 356   357      PinkPanther    Películas, Animación   20100000.0
# 3       4         SETIndia                     NaN  162600000.0
#
#             Country     Visits     Likes  Comments  \
# 75   Estados Unidos      160.0       3.0       0.0
# 429        Colombia    26300.0    2000.0      92.0
# 865          México   414000.0   15200.0     472.0
# 473          México   133400.0   10000.0      72.0
# 686  Estados Unidos  2700000.0  152400.0    1100.0
# 532          México   623600.0   39500.0     746.0
# 523  Estados Unidos  1800000.0   54600.0    1800.0
# 356         Unknown   274200.0    1700.0       0.0
# 3             India    15600.0     166.0       9.0
#
#                                                  Links
# 75   http://youtube.com/channel/UCsT0YIqwnpJCM-mx7-...
# 429  http://youtube.com/channel/UCssFxr-IdIa-wpG3jU...
# 865  http://youtube.com/channel/UCp7wTrsCU7eICb5z69...
# 473  http://youtube.com/channel/UC8rNKrqBxJqL9izOOM...
# 686  http://youtube.com/channel/UCzTKskwIc_-a0cGvCX...
# 532  http://youtube.com/channel/UCNbwP-bKUlKrE_5qDw...
# 523  http://youtube.com/channel/UCd1fLoVFooPeWqCEYV...
# 356  http://youtube.com/channel/UCFeUyPY6W8qX8w2o6o...
# 3    http://youtube.com/channel/UCpEhnqL0y41EpW2TvW...

# %%
# df.groupby('Subscribers').mean().sort_values(by='Likes', ascending= False)
df_pl= df.groupby(['Country','Categories', 'Username']) [['Likes', 'Visits', 'Subscribers']].mean().head(13)
df_pl.head(2)
        #    sort=True) [['Comments']].mean

# df_fl =df[df['Likes'] > 100000]
# df_fl.head()
# df[df['Country'].str.contains('India')]
# Out:
#                                                       Likes     Visits  \
# Country        Categories             Username
# Arabia Saudita Animación, Videojuegos BanderitaX    88200.0  1200000.0
#                Música y baile         katakit_baby   1200.0   174500.0
#
#                                                     Subscribers
# Country        Categories             Username
# Arabia Saudita Animación, Videojuegos BanderitaX     13600000.0
#                Música y baile         katakit_baby   16000000.0

# %%
# df_pl2 =df_pl.transpose()
df_pl.plot()
# df_pl2.plot()
# Out:
# <Axes: xlabel='Country,Categories,Username'>

# %%
#outliers
df.boxplot()
# Out:
# <Axes: >

# %%
df.select_dtypes(include=[ 'number','float']).head()
# Out:
#    Rank  Subscribers       Visits      Likes  Comments
# 0     1  249500000.0      86200.0     2700.0      78.0
# 1     2  183500000.0  117400000.0  5300000.0   18500.0
# 2     3  165500000.0    7000000.0    24700.0       0.0
# 3     4  162600000.0      15600.0      166.0       9.0
# 4     5  113500000.0    3900000.0    12400.0       0.0
